# %% [markdown]
# # Função Tangente Hiperbólica
#
# Na Matemática, as funções hiperbólicas são análogas às funções trigonométricas comuns.
#
# As funções hiperbólicas básicas são:
#
# - Seno hiperbólico "sinh"
# - Cosseno hiperbólico "cosh"
#
# No qual podemos derivar:
#
# - **Tangente hiperbólica "tanh"**
# - Cossecante hiperbólica "cosech"
# - Secante hiperbólica "sech"
# - Cotangente hiperbólica "coth"
#
# A **tanh** ou **função de ativação tangente hiperbólica** tem a seguinte fórmula matemática:
#
# \begin{equation}
# \tanh x=\frac{\cosh x}{\sinh x} = \frac{e^x - e^{-x}}{e^x + e^{-x}}
# \end{equation}
#
# Ela basicamente recebe um número de valor real e coloca ele entre $-1$ e $+1$.
#
# Vejamos um exemplo da Função Tanh

# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

array_input = np.linspace(-np.pi, np.pi, 50) 
array_output = np.tanh(array_input) 
  
print("array de input : ", array_input) 
print("\narray de output: ", array_output)
# Out:
# array de input :  [-3.14159265 -3.01336438 -2.88513611 -2.75690784 -2.62867957 -2.5004513
#  -2.37222302 -2.24399475 -2.11576648 -1.98753821 -1.85930994 -1.73108167
#  -1.60285339 -1.47462512 -1.34639685 -1.21816858 -1.08994031 -0.96171204
#  -0.83348377 -0.70525549 -0.57702722 -0.44879895 -0.32057068 -0.19234241
#  -0.06411414  0.06411414  0.19234241  0.32057068  0.44879895  0.57702722
#   0.70525549  0.83348377  0.96171204  1.08994031  1.21816858  1.34639685
#   1.47462512  1.60285339  1.73108167  1.85930994  1.98753821  2.11576648
#   2.24399475  2.37222302  2.5004513   2.62867957  2.75690784  2.88513611
#   3.01336438  3.14159265]
#
# array de output:  [-0.99627208 -0.99518487 -0.99378158 -0.99197097 -0.9896359  -0.98662629
#  -0.98275031 -0.97776356 -0.971356   -0.96313649 -0.95261504 -0.93918363
#  -0.92209694 -0.90045608 -0.87320015 -0.83911311 -0.79685636 -0.74503955
#  -0.68234219 -0.60769305 -0.5205014  -0.42091124 -0.31002284 -0.19000505
# ...

# %%
plt.figure(figsize=(16,9))
plt.plot(array_input, array_output, linewidth=3, color='b')
plt.axis([-3,3,-1,1])
plt.plot([-3,3],[0,0],'k--',linewidth=3)
plt.plot([0,0],[-3,3],'k--',linewidth=3)
plt.title("Função Hiperbólica") 
plt.xlabel("Eixo X") 
plt.ylabel("Eixo Y") 
plt.grid()
plt.show()
